# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from collections import deque
import random
import sklearn.ensemble
import sklearn.tree
from sklearn.exceptions import NotFittedError
import sklearn.multioutput

# %%
env = gym.make('CartPole-v0')
env._max_episode_steps = 400

# %%
################################
# Trees Q-learning implementation #
################################

env.reset()
observation_space = env.observation_space
action_space = env.action_space

EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995
BATCH_SIZE = 32
GAMMA = 0.95

exploration_rate = 1
memory = deque(maxlen=1000)

forest = sklearn.ensemble.RandomForestRegressor(n_estimators=5,random_state=0)
classifier = sklearn.multioutput.MultiOutputRegressor(forest)

def select_action(state):
    global exploration_rate
    
    if np.random.rand() < exploration_rate:
        return action_space.sample()
    try:
        q_values = classifier.predict(state.reshape(1, -1))
        return np.argmax(q_values[0])
    except NotFittedError as e:
        return 0

def remember(last_state,action,reward,next_state,done):
    global memory
    memory.append((last_state,action,reward,next_state,done))

def experience_replay():
    global memory,EXPLORATION_MIN,EXPLORATION_DECAY,BATCH_SIZE,GAMMA,exploration_rate

    if len(memory) < BATCH_SIZE:
        return

    batch = random.sample(memory,BATCH_SIZE)
#     batch = memory
    
    X = np.empty((0,4))
    y = np.empty((0,2))
    for last_state, action, reward, next_state, done in batch:
        q_update = reward
        if not done:
            try:
                q_update = (reward + GAMMA * np.amax(classifier.predict(next_state.reshape(1, -1))[0]))
            except NotFittedError as e:
                q_update = reward 
        try:
            q_values = classifier.predict(last_state.reshape(1, -1))
        except NotFittedError as e:
            q_values = np.zeros(action_space.n).reshape(1, -1)
#         print(q_values)
        q_values[0][action] = q_update
#         print(q_values)
        
        X = np.append(X,np.array([last_state]),axis=0)
        y = np.append(y,np.array([q_values[0]]),axis=0)
    
    #fit
    classifier.fit(X,y)
    
    if exploration_rate > EXPLORATION_MIN:
        exploration_rate *= EXPLORATION_DECAY

# %%
#training loop
episodes = 10
episodes_steps = np.array([])
num_solved = 0

for episode_i in range(episodes):
    last_state = env.reset()
    steps = 0
    total_reward = 0
    
    while True:
#         env.render()
        steps += 1
        action = select_action(last_state)
        next_state, reward, done, info = env.step(action)
        reward = reward if not done else -reward
        remember(last_state,action,reward,next_state,done)
        experience_replay()
        
        total_reward += reward
        
        if done:
            print("Episode {} finished after {} steps with {} total reward".format(episode_i,steps,total_reward))
            if total_reward > 250:
                num_solved += 1
            break
    
        last_state = next_state
    
    episodes_steps = np.append(episodes_steps,steps)
    
    if num_solved > 10:
        break
        
env.close()

plt.plot(episodes_steps)
plt.show
# Out:
# Episode 0 finished after 20 steps with 18.0 total reward
# Episode 1 finished after 17 steps with 15.0 total reward
# Episode 2 finished after 13 steps with 11.0 total reward
# Episode 3 finished after 39 steps with 37.0 total reward
# Episode 4 finished after 22 steps with 20.0 total reward
# Episode 5 finished after 16 steps with 14.0 total reward
# Episode 6 finished after 44 steps with 42.0 total reward
# Episode 7 finished after 19 steps with 17.0 total reward
# Episode 8 finished after 36 steps with 34.0 total reward
# Episode 9 finished after 68 steps with 66.0 total reward
# Episode 10 finished after 29 steps with 27.0 total reward
# Episode 11 finished after 15 steps with 13.0 total reward
# Episode 12 finished after 69 steps with 67.0 total reward
# Episode 13 finished after 35 steps with 33.0 total reward
# Episode 14 finished after 19 steps with 17.0 total reward
# Episode 15 finished after 12 steps with 10.0 total reward
# Episode 16 finished after 58 steps with 56.0 total reward
# Episode 17 finished after 25 steps with 23.0 total reward
# Episode 18 finished after 28 steps with 26.0 total reward
# Episode 19 finished after 69 steps with 67.0 total reward
# Episode 20 finished after 42 steps with 40.0 total reward
# Episode 21 finished after 13 steps with 11.0 total reward
# Episode 22 finished after 28 steps with 26.0 total reward
# Episode 23 finished after 13 steps with 11.0 total reward
# Episode 24 finished after 37 steps with 35.0 total reward
# Episode 25 finished after 28 steps with 26.0 total reward
# Episode 26 finished after 31 steps with 29.0 total reward
# Episode 27 finished after 63 steps with 61.0 total reward
# Episode 28 finished after 30 steps with 28.0 total reward
# Episode 29 finished after 15 steps with 13.0 total reward
# Episode 30 finished after 18 steps with 16.0 total reward
# Episode 31 finished after 81 steps with 79.0 total reward
# Episode 32 finished after 58 steps with 56.0 total reward
# Episode 33 finished after 36 steps with 34.0 total reward
# Episode 34 finished after 12 steps with 10.0 total reward
# Episode 35 finished after 27 steps with 25.0 total reward
# Episode 36 finished after 10 steps with 8.0 total reward
# Episode 37 finished after 32 steps with 30.0 total reward
# Episode 38 finished after 58 steps with 56.0 total reward
# Episode 39 finished after 15 steps with 13.0 total reward
# Episode 40 finished after 44 steps with 42.0 total reward
# Episode 41 finished after 73 steps with 71.0 total reward
# Episode 42 finished after 37 steps with 35.0 total reward
# Episode 43 finished after 58 steps with 56.0 total reward
# Episode 44 finished after 28 steps with 26.0 total reward
# Episode 45 finished after 24 steps with 22.0 total reward
# Episode 46 finished after 27 steps with 25.0 total reward
# Episode 47 finished after 48 steps with 46.0 total reward
# Episode 48 finished after 27 steps with 25.0 total reward
# Episode 49 finished after 33 steps with 31.0 total reward
# Episode 50 finished after 58 steps with 56.0 total reward
# Episode 51 finished after 36 steps with 34.0 total reward
# Episode 52 finished after 73 steps with 71.0 total reward
# Episode 53 finished after 10 steps with 8.0 total reward
# Episode 54 finished after 66 steps with 64.0 total reward
# Episode 55 finished after 57 steps with 55.0 total reward
# Episode 56 finished after 58 steps with 56.0 total reward
# Episode 57 finished after 10 steps with 8.0 total reward
# Episode 58 finished after 34 steps with 32.0 total reward
# Episode 59 finished after 13 steps with 11.0 total reward
# Episode 60 finished after 25 steps with 23.0 total reward
# Episode 61 finished after 32 steps with 30.0 total reward
# Episode 62 finished after 20 steps with 18.0 total reward
# Episode 63 finished after 27 steps with 25.0 total reward
# Episode 64 finished after 82 steps with 80.0 total reward
# Episode 65 finished after 41 steps with 39.0 total reward
# Episode 66 finished after 56 steps with 54.0 total reward
# Episode 67 finished after 20 steps with 18.0 total reward
# Episode 68 finished after 76 steps with 74.0 total reward
# Episode 69 finished after 60 steps with 58.0 total reward
# Episode 70 finished after 13 steps with 11.0 total reward
# Episode 71 finished after 28 steps with 26.0 total reward
# Episode 72 finished after 32 steps with 30.0 total reward
# Episode 73 finished after 59 steps with 57.0 total reward
# Episode 74 finished after 58 steps with 56.0 total reward
# Episode 75 finished after 45 steps with 43.0 total reward
# Episode 76 finished after 21 steps with 19.0 total reward
# Episode 77 finished after 35 steps with 33.0 total reward
# Episode 78 finished after 31 steps with 29.0 total reward
# Episode 79 finished after 34 steps with 32.0 total reward
# Episode 80 finished after 22 steps with 20.0 total reward
# Episode 81 finished after 12 steps with 10.0 total reward
# Episode 82 finished after 18 steps with 16.0 total reward
# Episode 83 finished after 44 steps with 42.0 total reward
# Episode 84 finished after 80 steps with 78.0 total reward
# Episode 85 finished after 52 steps with 50.0 total reward
# Episode 86 finished after 53 steps with 51.0 total reward
# Episode 87 finished after 42 steps with 40.0 total reward
# Episode 88 finished after 60 steps with 58.0 total reward
# Episode 89 finished after 32 steps with 30.0 total reward
# Episode 90 finished after 24 steps with 22.0 total reward
# Episode 91 finished after 27 steps with 25.0 total reward
# Episode 92 finished after 40 steps with 38.0 total reward
# Episode 93 finished after 18 steps with 16.0 total reward
# Episode 94 finished after 9 steps with 7.0 total reward
# Episode 95 finished after 19 steps with 17.0 total reward
# Episode 96 finished after 26 steps with 24.0 total reward
# Episode 97 finished after 40 steps with 38.0 total reward
# Episode 98 finished after 69 steps with 67.0 total reward
# Episode 99 finished after 59 steps with 57.0 total reward
# Episode 100 finished after 33 steps with 31.0 total reward
# Episode 101 finished after 42 steps with 40.0 total reward
# Episode 102 finished after 59 steps with 57.0 total reward
# Episode 103 finished after 67 steps with 65.0 total reward
# Episode 104 finished after 76 steps with 74.0 total reward
# Episode 105 finished after 23 steps with 21.0 total reward
# Episode 106 finished after 35 steps with 33.0 total reward
# Episode 107 finished after 18 steps with 16.0 total reward
# Episode 108 finished after 85 steps with 83.0 total reward
# Episode 109 finished after 37 steps with 35.0 total reward
# Episode 110 finished after 47 steps with 45.0 total reward
# Episode 111 finished after 12 steps with 10.0 total reward
# Episode 112 finished after 54 steps with 52.0 total reward
# Episode 113 finished after 54 steps with 52.0 total reward
# Episode 114 finished after 32 steps with 30.0 total reward
# Episode 115 finished after 16 steps with 14.0 total reward
# Episode 116 finished after 15 steps with 13.0 total reward
# Episode 117 finished after 31 steps with 29.0 total reward
# Episode 118 finished after 22 steps with 20.0 total reward
# Episode 119 finished after 25 steps with 23.0 total reward
# Episode 120 finished after 48 steps with 46.0 total reward
# Episode 121 finished after 18 steps with 16.0 total reward
# Episode 122 finished after 41 steps with 39.0 total reward
# Episode 123 finished after 31 steps with 29.0 total reward
# Episode 124 finished after 87 steps with 85.0 total reward
# Episode 125 finished after 25 steps with 23.0 total reward
# Episode 126 finished after 57 steps with 55.0 total reward
# Episode 127 finished after 49 steps with 47.0 total reward
# Episode 128 finished after 34 steps with 32.0 total reward
# Episode 129 finished after 15 steps with 13.0 total reward
# Episode 130 finished after 31 steps with 29.0 total reward
# Episode 131 finished after 73 steps with 71.0 total reward
# Episode 132 finished after 13 steps with 11.0 total reward
# Episode 133 finished after 14 steps with 12.0 total reward
# Episode 134 finished after 83 steps with 81.0 total reward
# Episode 135 finished after 26 steps with 24.0 total reward
# Episode 136 finished after 13 steps with 11.0 total reward
# Episode 137 finished after 24 steps with 22.0 total reward
# Episode 138 finished after 13 steps with 11.0 total reward
# Episode 139 finished after 10 steps with 8.0 total reward
# Episode 140 finished after 34 steps with 32.0 total reward
# Episode 141 finished after 16 steps with 14.0 total reward
# Episode 142 finished after 23 steps with 21.0 total reward
# Episode 143 finished after 47 steps with 45.0 total reward
# Episode 144 finished after 49 steps with 47.0 total reward
# Episode 145 finished after 55 steps with 53.0 total reward
# Episode 146 finished after 25 steps with 23.0 total reward
# Episode 147 finished after 58 steps with 56.0 total reward
# Episode 148 finished after 31 steps with 29.0 total reward
# Episode 149 finished after 22 steps with 20.0 total reward
# Episode 150 finished after 36 steps with 34.0 total reward
# Episode 151 finished after 28 steps with 26.0 total reward
# Episode 152 finished after 22 steps with 20.0 total reward
# Episode 153 finished after 30 steps with 28.0 total reward
# Episode 154 finished after 37 steps with 35.0 total reward
# Episode 155 finished after 104 steps with 102.0 total reward
# Episode 156 finished after 30 steps with 28.0 total reward
# Episode 157 finished after 40 steps with 38.0 total reward
# Episode 158 finished after 27 steps with 25.0 total reward
# Episode 159 finished after 52 steps with 50.0 total reward
# Episode 160 finished after 16 steps with 14.0 total reward
# Episode 161 finished after 31 steps with 29.0 total reward
# Episode 162 finished after 45 steps with 43.0 total reward
# Episode 163 finished after 10 steps with 8.0 total reward
# Episode 164 finished after 34 steps with 32.0 total reward
# Episode 165 finished after 35 steps with 33.0 total reward
# Episode 166 finished after 34 steps with 32.0 total reward
# Episode 167 finished after 25 steps with 23.0 total reward
# Episode 168 finished after 13 steps with 11.0 total reward
# Episode 169 finished after 18 steps with 16.0 total reward
# Episode 170 finished after 26 steps with 24.0 total reward
# Episode 171 finished after 15 steps with 13.0 total reward
# Episode 172 finished after 50 steps with 48.0 total reward
# Episode 173 finished after 38 steps with 36.0 total reward
# Episode 174 finished after 53 steps with 51.0 total reward
# Episode 175 finished after 31 steps with 29.0 total reward
# Episode 176 finished after 64 steps with 62.0 total reward
# Episode 177 finished after 21 steps with 19.0 total reward
# Episode 178 finished after 23 steps with 21.0 total reward
# Episode 179 finished after 78 steps with 76.0 total reward
# Episode 180 finished after 31 steps with 29.0 total reward
# Episode 181 finished after 34 steps with 32.0 total reward
# Episode 182 finished after 23 steps with 21.0 total reward
# Episode 183 finished after 36 steps with 34.0 total reward
# Episode 184 finished after 38 steps with 36.0 total reward
# Episode 185 finished after 40 steps with 38.0 total reward
# Episode 186 finished after 41 steps with 39.0 total reward
# Episode 187 finished after 26 steps with 24.0 total reward
# Episode 188 finished after 32 steps with 30.0 total reward
# Episode 189 finished after 13 steps with 11.0 total reward
# Episode 190 finished after 22 steps with 20.0 total reward
# Episode 191 finished after 12 steps with 10.0 total reward
# Episode 192 finished after 20 steps with 18.0 total reward
# Episode 193 finished after 64 steps with 62.0 total reward
# Episode 194 finished after 23 steps with 21.0 total reward
# Episode 195 finished after 42 steps with 40.0 total reward
# Episode 196 finished after 34 steps with 32.0 total reward
# Episode 197 finished after 18 steps with 16.0 total reward
# Episode 198 finished after 22 steps with 20.0 total reward
# Episode 199 finished after 25 steps with 23.0 total reward
# Episode 200 finished after 58 steps with 56.0 total reward
# Episode 201 finished after 28 steps with 26.0 total reward
# Episode 202 finished after 86 steps with 84.0 total reward
# Episode 203 finished after 25 steps with 23.0 total reward
# Episode 204 finished after 22 steps with 20.0 total reward
# Episode 205 finished after 24 steps with 22.0 total reward
# Episode 206 finished after 16 steps with 14.0 total reward
# Episode 207 finished after 37 steps with 35.0 total reward
# Episode 208 finished after 10 steps with 8.0 total reward
# Episode 209 finished after 119 steps with 117.0 total reward
# Episode 210 finished after 53 steps with 51.0 total reward
# Episode 211 finished after 17 steps with 15.0 total reward
# Episode 212 finished after 22 steps with 20.0 total reward
# Episode 213 finished after 11 steps with 9.0 total reward
# Episode 214 finished after 11 steps with 9.0 total reward
# Episode 215 finished after 46 steps with 44.0 total reward
# Episode 216 finished after 11 steps with 9.0 total reward
# Episode 217 finished after 12 steps with 10.0 total reward
# Episode 218 finished after 69 steps with 67.0 total reward
# Episode 219 finished after 36 steps with 34.0 total reward
# Episode 220 finished after 33 steps with 31.0 total reward
# Episode 221 finished after 113 steps with 111.0 total reward
# Episode 222 finished after 17 steps with 15.0 total reward
# Episode 223 finished after 41 steps with 39.0 total reward
# Episode 224 finished after 14 steps with 12.0 total reward
# Episode 225 finished after 32 steps with 30.0 total reward
# Episode 226 finished after 10 steps with 8.0 total reward
# Episode 227 finished after 20 steps with 18.0 total reward
# Episode 228 finished after 21 steps with 19.0 total reward
# Episode 229 finished after 12 steps with 10.0 total reward
# Episode 230 finished after 99 steps with 97.0 total reward
# Episode 231 finished after 9 steps with 7.0 total reward
# Episode 232 finished after 50 steps with 48.0 total reward
# Episode 233 finished after 14 steps with 12.0 total reward
# Episode 234 finished after 22 steps with 20.0 total reward
# Episode 235 finished after 10 steps with 8.0 total reward
# Episode 236 finished after 16 steps with 14.0 total reward
# Episode 237 finished after 40 steps with 38.0 total reward
# Episode 238 finished after 24 steps with 22.0 total reward
# Episode 239 finished after 29 steps with 27.0 total reward
# Episode 240 finished after 70 steps with 68.0 total reward
# Episode 241 finished after 56 steps with 54.0 total reward
# Episode 242 finished after 35 steps with 33.0 total reward
# Episode 243 finished after 19 steps with 17.0 total reward
# Episode 244 finished after 13 steps with 11.0 total reward
# Episode 245 finished after 91 steps with 89.0 total reward
# Episode 246 finished after 28 steps with 26.0 total reward
# Episode 247 finished after 26 steps with 24.0 total reward
# Episode 248 finished after 10 steps with 8.0 total reward
# Episode 249 finished after 22 steps with 20.0 total reward
# Episode 250 finished after 13 steps with 11.0 total reward
# Episode 251 finished after 31 steps with 29.0 total reward
# Episode 252 finished after 62 steps with 60.0 total reward
# Episode 253 finished after 20 steps with 18.0 total reward
# Episode 254 finished after 22 steps with 20.0 total reward
# Episode 255 finished after 28 steps with 26.0 total reward
# Episode 256 finished after 11 steps with 9.0 total reward
# Episode 257 finished after 11 steps with 9.0 total reward
# Episode 258 finished after 13 steps with 11.0 total reward
# Episode 259 finished after 30 steps with 28.0 total reward
# Episode 260 finished after 16 steps with 14.0 total reward
# Episode 261 finished after 59 steps with 57.0 total reward
# Episode 262 finished after 17 steps with 15.0 total reward
# Episode 263 finished after 30 steps with 28.0 total reward
# Episode 264 finished after 27 steps with 25.0 total reward
# Episode 265 finished after 50 steps with 48.0 total reward
# Episode 266 finished after 12 steps with 10.0 total reward
# Episode 267 finished after 20 steps with 18.0 total reward
# Episode 268 finished after 11 steps with 9.0 total reward
# Episode 269 finished after 66 steps with 64.0 total reward
# Episode 270 finished after 10 steps with 8.0 total reward
# Episode 271 finished after 9 steps with 7.0 total reward
# Episode 272 finished after 40 steps with 38.0 total reward
# Episode 273 finished after 51 steps with 49.0 total reward
# Episode 274 finished after 40 steps with 38.0 total reward
# Episode 275 finished after 41 steps with 39.0 total reward
# Episode 276 finished after 25 steps with 23.0 total reward
# Episode 277 finished after 25 steps with 23.0 total reward
# Episode 278 finished after 61 steps with 59.0 total reward
# Episode 279 finished after 23 steps with 21.0 total reward
# Episode 280 finished after 43 steps with 41.0 total reward
# Episode 281 finished after 12 steps with 10.0 total reward
# Episode 282 finished after 52 steps with 50.0 total reward
# Episode 283 finished after 9 steps with 7.0 total reward
# Episode 284 finished after 74 steps with 72.0 total reward
# Episode 285 finished after 12 steps with 10.0 total reward
# Episode 286 finished after 13 steps with 11.0 total reward
# Episode 287 finished after 45 steps with 43.0 total reward
# Episode 288 finished after 38 steps with 36.0 total reward
# Episode 289 finished after 37 steps with 35.0 total reward
# Episode 290 finished after 23 steps with 21.0 total reward
# Episode 291 finished after 33 steps with 31.0 total reward
# Episode 292 finished after 19 steps with 17.0 total reward
# Episode 293 finished after 42 steps with 40.0 total reward
# Episode 294 finished after 15 steps with 13.0 total reward
# Episode 295 finished after 33 steps with 31.0 total reward
# Episode 296 finished after 42 steps with 40.0 total reward
# Episode 297 finished after 28 steps with 26.0 total reward
# Episode 298 finished after 22 steps with 20.0 total reward
# Episode 299 finished after 14 steps with 12.0 total reward
# <function matplotlib.pyplot.show(close=None, block=None)>
