# %% [markdown]
# # OpenAI Gym Pendulum
# ## Solved using Q learning and neural networks
#
# #### References
# Inspiration for this project:
# - https://towardsdatascience.com/reinforcement-learning-q-learning-with-decision-trees-ecb1215d9131
# - https://www.semanticscholar.org/paper/Reinforcement-Learning-with-Decision-Trees-Pyeatt/f9b30e1f6d85cb77e95ff1d580ee67d7406f1dd6?p2df
#
# Github Repo solving OpenAI pendulum using the same method:
# - https://github.com/gsurma/cartpole

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import torch
from collections import deque
import random
import timeit

# %%
class NNpredictor():
    
    #init model and hyperparameters
    def __init__(self,input_shape,output_shape,env,exploration_min = 0.01, exploration_decay = 0.996,
                 exploration_rate = 1, batch_size = 32, gamma = 0.95, lr=0.001):
        self.env = env
        
        #models hyperparameters
        self.exploration_min = exploration_min
        self.exploration_decay = exploration_decay
        self.exploration_rate = exploration_rate
        self.batch_size = batch_size
        self.gamma = gamma
        self.lr = lr
        
        #model architecture
        self.model = torch.nn.Sequential(
            torch.nn.Linear(input_shape,32),
            torch.nn.ReLU(),
            torch.nn.Linear(32,32),
            torch.nn.ReLU(),
            torch.nn.Linear(32,output_shape),
        )
        self.loss = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr)
        
        self.memory = deque(maxlen=1000000)
        
        
    #select an action, either random or from model
    def select_action(self,state):
        #this ensures that the model explores the environment and accumulates memory (stochasticity)
        if np.random.rand() < self.exploration_rate:
            return self.env.action_space.sample()
        
        state = torch.from_numpy(state.astype("float32")) 
        q_values = self.model(state)
        return torch.argmax(q_values).item()


    #add an experience to the model's memory
    def remember(self,last_state,action,reward,next_state,done):
        self.memory.append((last_state,action,reward,next_state,done))

        
    #replay experiences from memory and fit the model
    def experience_replay(self,logs,episode):

        if len(self.memory) < self.batch_size:
            return

        batch = random.sample(self.memory,self.batch_size)

        running_loss = 0
        for last_state, action, reward, next_state, done in batch:
            q_update = reward
            if not done:
                #calculate what q value should have been for selected action
                q_update = (reward + self.gamma * torch.amax(self.model(torch.from_numpy(next_state.astype("float32")))).item())
            q_values = self.model(torch.from_numpy(last_state.astype("float32")))
            q_values[action] = q_update

            #fit
            l = self.loss(self.model(torch.from_numpy(last_state.astype("float32"))), q_values)
            self.model.zero_grad()
            l.backward()
            self.optimizer.step()
            running_loss += l.item()
        
        try:
            logs.episodes_loss[episode-1] += running_loss/self.batch_size
        except IndexError:
            logs.episodes_loss = np.append(logs.episodes_loss,running_loss/self.batch_size)

        #decay exploration rate to reduce randomness
        if self.exploration_rate > self.exploration_min:
            self.exploration_rate *= self.exploration_decay

# %%
class MetricsLogger():
    
    def __init__(self):
        self.episodes_steps = np.array([])
        self.episodes_before_solve = np.array([])
        self.episodes_loss = np.array([])
        self.runs_logs = np.empty((0,4))
        
    def reset_run(self):
        self.episodes_steps = np.array([])
        self.episodes_before_solve = np.array([])
        self.episodes_loss = np.array([])

# %%
#Init environment
env = gym.make('CartPole-v0')
env._max_episode_steps = 200

#Init Logger
logs = MetricsLogger()

# %%
################################
# Training loop #
################################

for run_i in range(5):
    start = timeit.default_timer()
    num_solved = 0
    episode_i = 0
    episode_i_before_solve = 0
    logs.reset_run()
    
    #Init model
    model = NNpredictor(4,2,env)
    
    while num_solved < 5 and episode_i < 2000:

        episode_i += 1
        last_state = env.reset()
        steps = 0
        total_reward = 0
        episode_i_before_solve += 1

        while True:
            running_loss = 0
            #uncomment this to display simulation 
    #         env.render()
            steps += 1
            action = model.select_action(last_state)
            next_state, reward, done, info = env.step(action)
            reward = reward if not done else -reward
            model.remember(last_state,action,reward,next_state,done)
            model.experience_replay(logs,episode_i)

            total_reward += reward

            if done:
                print("Episode {} finished after {} steps with {} total reward".format(episode_i,steps,total_reward))
                if total_reward > 190:
                    logs.episodes_before_solve = np.append(logs.episodes_before_solve,episode_i_before_solve)
                    episode_i_before_solve = 0
                    num_solved += 1
                break

            last_state = next_state

        logs.episodes_steps = np.append(logs.episodes_steps,steps)

    stop = timeit.default_timer()
    print("Run {} done in {}".format(run_i,stop - start))
    
    logs.runs_logs = np.append(logs.runs_logs,[[logs.episodes_steps,logs.episodes_before_solve,logs.episodes_loss,stop - start]],axis=0)
    
env.close()
# Out:
# Episode 1 finished after 23 steps with 21.0 total reward
# Episode 2 finished after 16 steps with 14.0 total reward
# Episode 3 finished after 19 steps with 17.0 total reward
# Episode 4 finished after 21 steps with 19.0 total reward
# Episode 5 finished after 31 steps with 29.0 total reward
# Episode 6 finished after 18 steps with 16.0 total reward
# Episode 7 finished after 15 steps with 13.0 total reward
# Episode 8 finished after 17 steps with 15.0 total reward
# Episode 9 finished after 14 steps with 12.0 total reward
# Episode 10 finished after 12 steps with 10.0 total reward
# Episode 11 finished after 13 steps with 11.0 total reward
# Episode 12 finished after 13 steps with 11.0 total reward
# Episode 13 finished after 12 steps with 10.0 total reward
# Episode 14 finished after 11 steps with 9.0 total reward
# Episode 15 finished after 15 steps with 13.0 total reward
# Episode 16 finished after 10 steps with 8.0 total reward
# Episode 17 finished after 11 steps with 9.0 total reward
# Episode 18 finished after 11 steps with 9.0 total reward
# Episode 19 finished after 13 steps with 11.0 total reward
# Episode 20 finished after 12 steps with 10.0 total reward
# Episode 21 finished after 10 steps with 8.0 total reward
# Episode 22 finished after 21 steps with 19.0 total reward
# Episode 23 finished after 11 steps with 9.0 total reward
# Episode 24 finished after 10 steps with 8.0 total reward
# Episode 25 finished after 13 steps with 11.0 total reward
# Episode 26 finished after 9 steps with 7.0 total reward
# Episode 27 finished after 12 steps with 10.0 total reward
# Episode 28 finished after 10 steps with 8.0 total reward
# Episode 29 finished after 10 steps with 8.0 total reward
# Episode 30 finished after 9 steps with 7.0 total reward
# Episode 31 finished after 11 steps with 9.0 total reward
# Episode 32 finished after 10 steps with 8.0 total reward
# Episode 33 finished after 11 steps with 9.0 total reward
# Episode 34 finished after 10 steps with 8.0 total reward
# Episode 35 finished after 9 steps with 7.0 total reward
# Episode 36 finished after 11 steps with 9.0 total reward
# Episode 37 finished after 15 steps with 13.0 total reward
# Episode 38 finished after 9 steps with 7.0 total reward
# Episode 39 finished after 8 steps with 6.0 total reward
# Episode 40 finished after 10 steps with 8.0 total reward
# Episode 41 finished after 10 steps with 8.0 total reward
# Episode 42 finished after 10 steps with 8.0 total reward
# Episode 43 finished after 10 steps with 8.0 total reward
# Episode 44 finished after 10 steps with 8.0 total reward
# Episode 45 finished after 10 steps with 8.0 total reward
# Episode 46 finished after 11 steps with 9.0 total reward
# Episode 47 finished after 10 steps with 8.0 total reward
# Episode 48 finished after 13 steps with 11.0 total reward
# Episode 49 finished after 9 steps with 7.0 total reward
# Episode 50 finished after 9 steps with 7.0 total reward
# Episode 51 finished after 10 steps with 8.0 total reward
# Episode 52 finished after 10 steps with 8.0 total reward
# Episode 53 finished after 10 steps with 8.0 total reward
# Episode 54 finished after 10 steps with 8.0 total reward
# Episode 55 finished after 12 steps with 10.0 total reward
# Episode 56 finished after 14 steps with 12.0 total reward
# Episode 57 finished after 31 steps with 29.0 total reward
# Episode 58 finished after 52 steps with 50.0 total reward
# Episode 59 finished after 44 steps with 42.0 total reward
# Episode 60 finished after 18 steps with 16.0 total reward
# Episode 61 finished after 19 steps with 17.0 total reward
# Episode 62 finished after 30 steps with 28.0 total reward
# Episode 63 finished after 18 steps with 16.0 total reward
# Episode 64 finished after 21 steps with 19.0 total reward
# Episode 65 finished after 21 steps with 19.0 total reward
# Episode 66 finished after 12 steps with 10.0 total reward
# Episode 67 finished after 14 steps with 12.0 total reward
# Episode 68 finished after 39 steps with 37.0 total reward
# Episode 69 finished after 22 steps with 20.0 total reward
# Episode 70 finished after 12 steps with 10.0 total reward
# Episode 71 finished after 33 steps with 31.0 total reward
# Episode 72 finished after 9 steps with 7.0 total reward
# Episode 73 finished after 40 steps with 38.0 total reward
# Episode 74 finished after 12 steps with 10.0 total reward
# Episode 75 finished after 33 steps with 31.0 total reward
# Episode 76 finished after 35 steps with 33.0 total reward
# Episode 77 finished after 71 steps with 69.0 total reward
# Episode 78 finished after 29 steps with 27.0 total reward
# Episode 79 finished after 31 steps with 29.0 total reward
# Episode 80 finished after 23 steps with 21.0 total reward
# Episode 81 finished after 44 steps with 42.0 total reward
# Episode 82 finished after 34 steps with 32.0 total reward
# Episode 83 finished after 17 steps with 15.0 total reward
# Episode 84 finished after 42 steps with 40.0 total reward
# Episode 85 finished after 67 steps with 65.0 total reward
# Episode 86 finished after 15 steps with 13.0 total reward
# Episode 87 finished after 13 steps with 11.0 total reward
# Episode 88 finished after 16 steps with 14.0 total reward
# Episode 89 finished after 38 steps with 36.0 total reward
# Episode 90 finished after 12 steps with 10.0 total reward
# Episode 91 finished after 44 steps with 42.0 total reward
# Episode 92 finished after 17 steps with 15.0 total reward
# Episode 93 finished after 44 steps with 42.0 total reward
# Episode 94 finished after 49 steps with 47.0 total reward
# Episode 95 finished after 40 steps with 38.0 total reward
# Episode 96 finished after 11 steps with 9.0 total reward
# Episode 97 finished after 12 steps with 10.0 total reward
# Episode 98 finished after 61 steps with 59.0 total reward
# Episode 99 finished after 50 steps with 48.0 total reward
# Episode 100 finished after 31 steps with 29.0 total reward
# Episode 101 finished after 48 steps with 46.0 total reward
# Episode 102 finished after 19 steps with 17.0 total reward
# Episode 103 finished after 12 steps with 10.0 total reward
# Episode 104 finished after 41 steps with 39.0 total reward
# Episode 105 finished after 95 steps with 93.0 total reward
# Episode 106 finished after 27 steps with 25.0 total reward
# Episode 107 finished after 42 steps with 40.0 total reward
# Episode 108 finished after 18 steps with 16.0 total reward
# Episode 109 finished after 16 steps with 14.0 total reward
# Episode 110 finished after 26 steps with 24.0 total reward
# Episode 111 finished after 17 steps with 15.0 total reward
# Episode 112 finished after 18 steps with 16.0 total reward
# Episode 113 finished after 32 steps with 30.0 total reward
# Episode 114 finished after 26 steps with 24.0 total reward
# Episode 115 finished after 15 steps with 13.0 total reward
# Episode 116 finished after 17 steps with 15.0 total reward
# Episode 117 finished after 33 steps with 31.0 total reward
# Episode 118 finished after 18 steps with 16.0 total reward
# Episode 119 finished after 24 steps with 22.0 total reward
# Episode 120 finished after 18 steps with 16.0 total reward
# Episode 121 finished after 29 steps with 27.0 total reward
# Episode 122 finished after 16 steps with 14.0 total reward
# Episode 123 finished after 25 steps with 23.0 total reward
# Episode 124 finished after 21 steps with 19.0 total reward
# Episode 125 finished after 18 steps with 16.0 total reward
# Episode 126 finished after 25 steps with 23.0 total reward
# Episode 127 finished after 49 steps with 47.0 total reward
# Episode 128 finished after 16 steps with 14.0 total reward
# Episode 129 finished after 40 steps with 38.0 total reward
# Episode 130 finished after 113 steps with 111.0 total reward
# Episode 131 finished after 200 steps with 198.0 total reward
# Episode 132 finished after 157 steps with 155.0 total reward
# Episode 133 finished after 200 steps with 198.0 total reward
# Episode 134 finished after 114 steps with 112.0 total reward
# Episode 135 finished after 73 steps with 71.0 total reward
# Episode 136 finished after 19 steps with 17.0 total reward
# Episode 137 finished after 88 steps with 86.0 total reward
# Episode 138 finished after 118 steps with 116.0 total reward
# Episode 139 finished after 125 steps with 123.0 total reward
# Episode 140 finished after 200 steps with 198.0 total reward
# Episode 141 finished after 132 steps with 130.0 total reward
# Episode 142 finished after 186 steps with 184.0 total reward
# Episode 143 finished after 121 steps with 119.0 total reward
# Episode 144 finished after 151 steps with 149.0 total reward
# Episode 145 finished after 134 steps with 132.0 total reward
# Episode 146 finished after 148 steps with 146.0 total reward
# Episode 147 finished after 190 steps with 188.0 total reward
# Episode 148 finished after 164 steps with 162.0 total reward
# Episode 149 finished after 155 steps with 153.0 total reward
# Episode 150 finished after 200 steps with 198.0 total reward
# Episode 151 finished after 200 steps with 198.0 total reward
# Run 0 done in 234.90462549999938
# Episode 1 finished after 16 steps with 14.0 total reward
# Episode 2 finished after 19 steps with 17.0 total reward
# Episode 3 finished after 16 steps with 14.0 total reward
# Episode 4 finished after 21 steps with 19.0 total reward
# Episode 5 finished after 19 steps with 17.0 total reward
# Episode 6 finished after 13 steps with 11.0 total reward
# Episode 7 finished after 12 steps with 10.0 total reward
# Episode 8 finished after 10 steps with 8.0 total reward
# Episode 9 finished after 19 steps with 17.0 total reward
# Episode 10 finished after 11 steps with 9.0 total reward
# Episode 11 finished after 9 steps with 7.0 total reward
# Episode 12 finished after 28 steps with 26.0 total reward
# Episode 13 finished after 32 steps with 30.0 total reward
# Episode 14 finished after 26 steps with 24.0 total reward
# Episode 15 finished after 24 steps with 22.0 total reward
# Episode 16 finished after 42 steps with 40.0 total reward
# Episode 17 finished after 30 steps with 28.0 total reward
# Episode 18 finished after 49 steps with 47.0 total reward
# Episode 19 finished after 40 steps with 38.0 total reward
# Episode 20 finished after 32 steps with 30.0 total reward
# Episode 21 finished after 108 steps with 106.0 total reward
# Episode 22 finished after 146 steps with 144.0 total reward
# Episode 23 finished after 152 steps with 150.0 total reward
# Episode 24 finished after 162 steps with 160.0 total reward
# Episode 25 finished after 132 steps with 130.0 total reward
# Episode 26 finished after 131 steps with 129.0 total reward
# Episode 27 finished after 159 steps with 157.0 total reward
# Episode 28 finished after 148 steps with 146.0 total reward
# Episode 29 finished after 144 steps with 142.0 total reward
# Episode 30 finished after 140 steps with 138.0 total reward
# Episode 31 finished after 144 steps with 142.0 total reward
# Episode 32 finished after 144 steps with 142.0 total reward
# Episode 33 finished after 156 steps with 154.0 total reward
# Episode 34 finished after 136 steps with 134.0 total reward
# Episode 35 finished after 137 steps with 135.0 total reward
# Episode 36 finished after 143 steps with 141.0 total reward
# Episode 37 finished after 140 steps with 138.0 total reward
# Episode 38 finished after 145 steps with 143.0 total reward
# Episode 39 finished after 136 steps with 134.0 total reward
# Episode 40 finished after 140 steps with 138.0 total reward
# Episode 41 finished after 133 steps with 131.0 total reward
# Episode 42 finished after 156 steps with 154.0 total reward
# Episode 43 finished after 129 steps with 127.0 total reward
# Episode 44 finished after 144 steps with 142.0 total reward
# Episode 45 finished after 142 steps with 140.0 total reward
# Episode 46 finished after 129 steps with 127.0 total reward
# Episode 47 finished after 153 steps with 151.0 total reward
# Episode 48 finished after 135 steps with 133.0 total reward
# Episode 49 finished after 128 steps with 126.0 total reward
# Episode 50 finished after 130 steps with 128.0 total reward
# Episode 51 finished after 129 steps with 127.0 total reward
# Episode 52 finished after 131 steps with 129.0 total reward
# Episode 53 finished after 141 steps with 139.0 total reward
# Episode 54 finished after 149 steps with 147.0 total reward
# Episode 55 finished after 151 steps with 149.0 total reward
# Episode 56 finished after 156 steps with 154.0 total reward
# Episode 57 finished after 184 steps with 182.0 total reward
# Episode 58 finished after 143 steps with 141.0 total reward
# Episode 59 finished after 156 steps with 154.0 total reward
# Episode 60 finished after 169 steps with 167.0 total reward
# Episode 61 finished after 156 steps with 154.0 total reward
# Episode 62 finished after 200 steps with 198.0 total reward
# Episode 63 finished after 98 steps with 96.0 total reward
# Episode 64 finished after 188 steps with 186.0 total reward
# Episode 65 finished after 147 steps with 145.0 total reward
# Episode 66 finished after 162 steps with 160.0 total reward
# Episode 67 finished after 200 steps with 198.0 total reward
# Episode 68 finished after 58 steps with 56.0 total reward
# Episode 69 finished after 174 steps with 172.0 total reward
# Episode 70 finished after 200 steps with 198.0 total reward
# Episode 71 finished after 161 steps with 159.0 total reward
# Episode 72 finished after 200 steps with 198.0 total reward
# Episode 73 finished after 151 steps with 149.0 total reward
# Episode 74 finished after 12 steps with 10.0 total reward
# Episode 75 finished after 136 steps with 134.0 total reward
# Episode 76 finished after 168 steps with 166.0 total reward
# Episode 77 finished after 71 steps with 69.0 total reward
# Episode 78 finished after 172 steps with 170.0 total reward
# Episode 79 finished after 200 steps with 198.0 total reward
# Run 1 done in 350.5755145999865
# Episode 1 finished after 22 steps with 20.0 total reward
# Episode 2 finished after 37 steps with 35.0 total reward
# Episode 3 finished after 18 steps with 16.0 total reward
# Episode 4 finished after 33 steps with 31.0 total reward
# Episode 5 finished after 29 steps with 27.0 total reward
# Episode 6 finished after 26 steps with 24.0 total reward
# Episode 7 finished after 13 steps with 11.0 total reward
# Episode 8 finished after 24 steps with 22.0 total reward
# Episode 9 finished after 128 steps with 126.0 total reward
# Episode 10 finished after 82 steps with 80.0 total reward
# Episode 11 finished after 155 steps with 153.0 total reward
# Episode 12 finished after 111 steps with 109.0 total reward
# Episode 13 finished after 127 steps with 125.0 total reward
# Episode 14 finished after 92 steps with 90.0 total reward
# Episode 15 finished after 200 steps with 198.0 total reward
# Episode 16 finished after 200 steps with 198.0 total reward
# Episode 17 finished after 75 steps with 73.0 total reward
# Episode 18 finished after 200 steps with 198.0 total reward
# Episode 19 finished after 154 steps with 152.0 total reward
# Episode 20 finished after 190 steps with 188.0 total reward
# Episode 21 finished after 200 steps with 198.0 total reward
# Episode 22 finished after 173 steps with 171.0 total reward
# Episode 23 finished after 116 steps with 114.0 total reward
# Episode 24 finished after 200 steps with 198.0 total reward
# Run 2 done in 99.24283740000101
# Episode 1 finished after 37 steps with 35.0 total reward
# Episode 2 finished after 15 steps with 13.0 total reward
# Episode 3 finished after 13 steps with 11.0 total reward
# Episode 4 finished after 28 steps with 26.0 total reward
# Episode 5 finished after 27 steps with 25.0 total reward
# Episode 6 finished after 16 steps with 14.0 total reward
# Episode 7 finished after 24 steps with 22.0 total reward
# Episode 8 finished after 9 steps with 7.0 total reward
# Episode 9 finished after 9 steps with 7.0 total reward
# Episode 10 finished after 15 steps with 13.0 total reward
# Episode 11 finished after 12 steps with 10.0 total reward
# Episode 12 finished after 18 steps with 16.0 total reward
# Episode 13 finished after 13 steps with 11.0 total reward
# Episode 14 finished after 11 steps with 9.0 total reward
# Episode 15 finished after 14 steps with 12.0 total reward
# Episode 16 finished after 13 steps with 11.0 total reward
# Episode 17 finished after 15 steps with 13.0 total reward
# Episode 18 finished after 10 steps with 8.0 total reward
# Episode 19 finished after 42 steps with 40.0 total reward
# Episode 20 finished after 35 steps with 33.0 total reward
# Episode 21 finished after 52 steps with 50.0 total reward
# Episode 22 finished after 37 steps with 35.0 total reward
# Episode 23 finished after 58 steps with 56.0 total reward
# Episode 24 finished after 36 steps with 34.0 total reward
# Episode 25 finished after 31 steps with 29.0 total reward
# Episode 26 finished after 67 steps with 65.0 total reward
# Episode 27 finished after 66 steps with 64.0 total reward
# Episode 28 finished after 105 steps with 103.0 total reward
# Episode 29 finished after 134 steps with 132.0 total reward
# Episode 30 finished after 80 steps with 78.0 total reward
# Episode 31 finished after 104 steps with 102.0 total reward
# Episode 32 finished after 125 steps with 123.0 total reward
# Episode 33 finished after 200 steps with 198.0 total reward
# Episode 34 finished after 160 steps with 158.0 total reward
# Episode 35 finished after 174 steps with 172.0 total reward
# Episode 36 finished after 131 steps with 129.0 total reward
# Episode 37 finished after 128 steps with 126.0 total reward
# Episode 38 finished after 180 steps with 178.0 total reward
# Episode 39 finished after 153 steps with 151.0 total reward
# Episode 40 finished after 158 steps with 156.0 total reward
# Episode 41 finished after 162 steps with 160.0 total reward
# Episode 42 finished after 142 steps with 140.0 total reward
# Episode 43 finished after 178 steps with 176.0 total reward
# Episode 44 finished after 138 steps with 136.0 total reward
# Episode 45 finished after 138 steps with 136.0 total reward
# Episode 46 finished after 157 steps with 155.0 total reward
# Episode 47 finished after 172 steps with 170.0 total reward
# Episode 48 finished after 145 steps with 143.0 total reward
# Episode 49 finished after 167 steps with 165.0 total reward
# Episode 50 finished after 174 steps with 172.0 total reward
# Episode 51 finished after 176 steps with 174.0 total reward
# Episode 52 finished after 153 steps with 151.0 total reward
# Episode 53 finished after 144 steps with 142.0 total reward
# Episode 54 finished after 150 steps with 148.0 total reward
# Episode 55 finished after 143 steps with 141.0 total reward
# Episode 56 finished after 166 steps with 164.0 total reward
# Episode 57 finished after 167 steps with 165.0 total reward
# Episode 58 finished after 136 steps with 134.0 total reward
# Episode 59 finished after 162 steps with 160.0 total reward
# Episode 60 finished after 176 steps with 174.0 total reward
# Episode 61 finished after 190 steps with 188.0 total reward
# Episode 62 finished after 197 steps with 195.0 total reward
# Episode 63 finished after 95 steps with 93.0 total reward
# Episode 64 finished after 185 steps with 183.0 total reward
# Episode 65 finished after 180 steps with 178.0 total reward
# Episode 66 finished after 162 steps with 160.0 total reward
# Episode 67 finished after 166 steps with 164.0 total reward
# Episode 68 finished after 166 steps with 164.0 total reward
# Episode 69 finished after 175 steps with 173.0 total reward
# Episode 70 finished after 176 steps with 174.0 total reward
# Episode 71 finished after 165 steps with 163.0 total reward
# Episode 72 finished after 159 steps with 157.0 total reward
# Episode 73 finished after 200 steps with 198.0 total reward
# Episode 74 finished after 200 steps with 198.0 total reward
# Episode 75 finished after 180 steps with 178.0 total reward
# Episode 76 finished after 158 steps with 156.0 total reward
# Episode 77 finished after 188 steps with 186.0 total reward
# Episode 78 finished after 146 steps with 144.0 total reward
# Episode 79 finished after 98 steps with 96.0 total reward
# Episode 80 finished after 200 steps with 198.0 total reward
# Run 3 done in 349.85066959999676
# Episode 1 finished after 17 steps with 15.0 total reward
# Episode 2 finished after 19 steps with 17.0 total reward
# Episode 3 finished after 19 steps with 17.0 total reward
# Episode 4 finished after 27 steps with 25.0 total reward
# Episode 5 finished after 24 steps with 22.0 total reward
# Episode 6 finished after 16 steps with 14.0 total reward
# Episode 7 finished after 18 steps with 16.0 total reward
# Episode 8 finished after 23 steps with 21.0 total reward
# Episode 9 finished after 9 steps with 7.0 total reward
# Episode 10 finished after 45 steps with 43.0 total reward
# Episode 11 finished after 14 steps with 12.0 total reward
# Episode 12 finished after 14 steps with 12.0 total reward
# Episode 13 finished after 10 steps with 8.0 total reward
# Episode 14 finished after 10 steps with 8.0 total reward
# Episode 15 finished after 13 steps with 11.0 total reward
# Episode 16 finished after 13 steps with 11.0 total reward
# Episode 17 finished after 9 steps with 7.0 total reward
# Episode 18 finished after 12 steps with 10.0 total reward
# Episode 19 finished after 14 steps with 12.0 total reward
# Episode 20 finished after 14 steps with 12.0 total reward
# Episode 21 finished after 8 steps with 6.0 total reward
# Episode 22 finished after 10 steps with 8.0 total reward
# Episode 23 finished after 12 steps with 10.0 total reward
# Episode 24 finished after 10 steps with 8.0 total reward
# Episode 25 finished after 9 steps with 7.0 total reward
# Episode 26 finished after 9 steps with 7.0 total reward
# Episode 27 finished after 9 steps with 7.0 total reward
# Episode 28 finished after 21 steps with 19.0 total reward
# Episode 29 finished after 16 steps with 14.0 total reward
# Episode 30 finished after 10 steps with 8.0 total reward
# Episode 31 finished after 9 steps with 7.0 total reward
# Episode 32 finished after 11 steps with 9.0 total reward
# Episode 33 finished after 14 steps with 12.0 total reward
# Episode 34 finished after 10 steps with 8.0 total reward
# Episode 35 finished after 9 steps with 7.0 total reward
# Episode 36 finished after 9 steps with 7.0 total reward
# Episode 37 finished after 12 steps with 10.0 total reward
# Episode 38 finished after 11 steps with 9.0 total reward
# Episode 39 finished after 10 steps with 8.0 total reward
# Episode 40 finished after 16 steps with 14.0 total reward
# Episode 41 finished after 17 steps with 15.0 total reward
# Episode 42 finished after 15 steps with 13.0 total reward
# Episode 43 finished after 13 steps with 11.0 total reward
# Episode 44 finished after 24 steps with 22.0 total reward
# Episode 45 finished after 13 steps with 11.0 total reward
# Episode 46 finished after 12 steps with 10.0 total reward
# Episode 47 finished after 17 steps with 15.0 total reward
# Episode 48 finished after 22 steps with 20.0 total reward
# Episode 49 finished after 23 steps with 21.0 total reward
# Episode 50 finished after 31 steps with 29.0 total reward
# Episode 51 finished after 43 steps with 41.0 total reward
# Episode 52 finished after 44 steps with 42.0 total reward
# Episode 53 finished after 33 steps with 31.0 total reward
# Episode 54 finished after 56 steps with 54.0 total reward
# Episode 55 finished after 32 steps with 30.0 total reward
# Episode 56 finished after 55 steps with 53.0 total reward
# Episode 57 finished after 143 steps with 141.0 total reward
# Episode 58 finished after 96 steps with 94.0 total reward
# Episode 59 finished after 48 steps with 46.0 total reward
# Episode 60 finished after 92 steps with 90.0 total reward
# Episode 61 finished after 127 steps with 125.0 total reward
# Episode 62 finished after 64 steps with 62.0 total reward
# Episode 63 finished after 39 steps with 37.0 total reward
# Episode 64 finished after 60 steps with 58.0 total reward
# Episode 65 finished after 34 steps with 32.0 total reward
# Episode 66 finished after 40 steps with 38.0 total reward
# Episode 67 finished after 35 steps with 33.0 total reward
# Episode 68 finished after 50 steps with 48.0 total reward
# Episode 69 finished after 57 steps with 55.0 total reward
# Episode 70 finished after 88 steps with 86.0 total reward
# Episode 71 finished after 79 steps with 77.0 total reward
# Episode 72 finished after 125 steps with 123.0 total reward
# Episode 73 finished after 73 steps with 71.0 total reward
# Episode 74 finished after 67 steps with 65.0 total reward
# Episode 75 finished after 173 steps with 171.0 total reward
# Episode 76 finished after 96 steps with 94.0 total reward
# Episode 77 finished after 152 steps with 150.0 total reward
# Episode 78 finished after 147 steps with 145.0 total reward
# Episode 79 finished after 184 steps with 182.0 total reward
# Episode 80 finished after 200 steps with 198.0 total reward
# Episode 81 finished after 200 steps with 198.0 total reward
# Episode 82 finished after 183 steps with 181.0 total reward
# Episode 83 finished after 200 steps with 198.0 total reward
# Episode 84 finished after 180 steps with 178.0 total reward
# Episode 85 finished after 161 steps with 159.0 total reward
# Episode 86 finished after 196 steps with 194.0 total reward
# Episode 87 finished after 173 steps with 171.0 total reward
# Episode 88 finished after 200 steps with 198.0 total reward
# Run 4 done in 180.600248799994

# %%
plt.figure(figsize=(16,16))
count = 0
for run_log in logs.runs_logs:
    count += 1
    plt.subplot(4,2,count,title="Number of steps per episode for run {}".format(count))
    plt.plot(run_log[0])
    plt.xlabel("episode number")
    plt.ylabel("number of steps")
    
plt.subplot(4,2,count+1,title="Number of steps per episode for all runs")
for run_log in logs.runs_logs:
    plt.plot(run_log[0])
plt.xlabel("episode number")
plt.ylabel("number of steps")
    
plt.tight_layout()
plt.show;

# %%
#####
# Everytime the env is solved, we look at the number of episodes it took before solving it.
# The peaks are at the start of each run, since the model is not yet trained.
####
cumul_episodes_before_solve = np.array([])
for run_log in logs.runs_logs:
    cumul_episodes_before_solve = np.append(cumul_episodes_before_solve,run_log[1])

average_episiodes_before_solve = np.sum(cumul_episodes_before_solve)/len(cumul_episodes_before_solve)

plt.figure(figsize=(10,5))
plt.plot(cumul_episodes_before_solve)
plt.hlines(average_episiodes_before_solve,0,25,linestyles="dashed",colors="orange")
plt.title("Number of episodes before solving environment")
plt.xlabel("trial number")
plt.ylabel("number of episodes")
plt.show;

# %%
cumul_steps_per_eps = np.array([])
cumul_time_per_run = np.array([])
for run_log in logs.runs_logs:
    cumul_steps_per_eps = np.append(cumul_steps_per_eps,run_log[0])
    cumul_time_per_run = np.append(cumul_time_per_run,run_log[3])

print("\nTotal number of steps per run:")
run_count = 0
for run_log in logs.runs_logs:
    run_count += 1
    print("\tRun {}, total steps : {}".format(run_count,np.sum(run_log[0])))

print("\nTotal number of steps: {}".format(np.sum(cumul_steps_per_eps)))
print("Average number of steps per run: {}".format(np.sum(cumul_steps_per_eps)/5))
print("\nAverage time per run: {} seconds".format(np.sum(cumul_time_per_run)/5))
print("Average time per step: {:.2f} seconds".format(np.sum(cumul_steps_per_eps)/np.sum(cumul_time_per_run)))
# Out:
# Total number of steps per run:
# 	Run 1, total steps : 6009.0
# 	Run 2, total steps : 9053.0
# 	Run 3, total steps : 2605.0
# 	Run 4, total steps : 9087.0
# 	Run 5, total steps : 4777.0
#
# Total number of steps: 31531.0
# Average number of steps per run: 6306.2
#
# Average time per run: 243.03477917999552 seconds
# Average time per step: 25.95 seconds
